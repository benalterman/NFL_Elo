# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('2019data.csv', low_memory=False)
data.head(1)
# Out:
#    Unnamed: 0  play_id     game_id home_team away_team posteam posteam_type  \
# 0           0       50  2019090500       CHI        GB      GB         away
#
#   defteam side_of_field  yardline_100   game_date  quarter_seconds_remaining  \
# 0     CHI            GB          75.0  2019-09-05                      900.0
#
#    half_seconds_remaining  game_seconds_remaining game_half  quarter_end  \
# 0                  1800.0                  3600.0     Half1            0
#
#    drive  sp  qtr  down  goal_to_go   time  yrdln  ydstogo  ydsnet  \
# 0      1   0    1   1.0         0.0  15:00  GB 25       10     -10
#
#                                                 desc play_type  yards_gained  \
# 0  (15:00) A.Jones left tackle to GB 25 for no ga...       run             0
#
#    shotgun  no_huddle  qb_dropback  qb_kneel  qb_spike  qb_scramble  \
# 0        0          0          0.0         0         0            0
#
# ...
