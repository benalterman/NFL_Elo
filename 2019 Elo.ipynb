# %%
# Imports

import pandas as pd
import numpy as np
from collections import OrderedDict

# %%
# Get data

df = pd.read_csv('rts.csv')
np = df.to_numpy()
keys = np[:,0]
values = np[:,1]
dict = {k: v for k, v in zip(keys, values)}

# %%
# Make variables

ari = dict.get('ARI'); atl = dict.get('ATL'); blt = dict.get('BAL'); buf = dict.get('BUF')
car = dict.get('CAR'); chi = dict.get('CHI'); cin = dict.get('CIN'); cle = dict.get('CLE')
dal = dict.get('DAL'); den = dict.get('DEN'); det = dict.get('DET'); gb = dict.get('GB')
hou = dict.get('HOU'); ind = dict.get('IND'); jax = dict.get('JAX'); kc = dict.get('KC')
lac = dict.get('LAC'); lar = dict.get('LAR'); mia = dict.get('MIA'); minn = dict.get('MIN')
no = dict.get('NO'); ne = dict.get('NE'); nyg = dict.get('NYG'); nyj = dict.get('NYJ'); 
oak = dict.get('OAK'); phi = dict.get('PHI'); pitt = dict.get('PIT'); sea = dict.get('SEA'); 
sf = dict.get('SF'); tb = dict.get('TB'); tenn = dict.get('TEN'); was = dict.get('WAS');

# %%
# Elo Rankings Table

teams = ['ARI', 'ATL', 'BLT', 'BUF', 'CAR', 'CHI', 'CIN', 'CLE',
        'DAL', 'DEN', 'DET', 'GB', 'HOU', 'IND', 'JAX', 'KC', 'LAC',
        'LAR', 'MIA', 'MIN', 'NO', 'NE', 'NYG', 'NYJ', 'OAK',
        'PHI', 'PITT', 'SEA', 'SF', 'TB', 'TENN', 'WASH']

elo = [ari, atl, blt, buf, car, chi, cin, cle,
        dal, den, det, gb, hou, ind, jax, kc, lac,
        lar, mia, minn, no, ne, nyg, nyj, oak,
        phi, pitt, sea, sf, tb, tenn, was]

rank = list(i+1 for i in range(32))

k = 0.1
playoff = 1.2

table = pd.DataFrame({'Teams':teams, 'Elo':elo})
table = table.sort_values(by=['Elo'], ascending=False)
table.insert(0, 'Rank', rank)
table = table.style.hide_index()
table
# Out:
# <style  type="text/css" >
# </style><table id="T_8a1972f6_310d_11ea_a347_8c859078f5a0" ><thead>    <tr>        <th class="col_heading level0 col0" >Rank</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Elo</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row0_col1" class="data row0 col1" >NO</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row0_col2" class="data row0 col2" >1800</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row1_col1" class="data row1 col1" >NE</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row1_col2" class="data row1 col2" >1800</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row2_col1" class="data row2 col1" >MIN</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row2_col2" class="data row2 col2" >1800</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row3_col1" class="data row3 col1" >PITT</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row3_col2" class="data row3 col2" >1800</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row4_col1" class="data row4 col1" >KC</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row4_col2" class="data row4 col2" >1750</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row5_col1" class="data row5 col1" >LAR</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row5_col2" class="data row5 col2" >1741</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row6_col1" class="data row6 col1" >PHI</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row6_col2" class="data row6 col2" >1664</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row7_col1" class="data row7 col1" >CAR</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row7_col2" class="data row7 col2" >1631</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row8_col0" class="data row8 col0" >9</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row8_col1" class="data row8 col1" >LAC</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row8_col2" class="data row8 col2" >1620</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row9_col0" class="data row9 col0" >10</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row9_col1" class="data row9 col1" >ATL</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row9_col2" class="data row9 col2" >1610</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row10_col0" class="data row10 col0" >11</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row10_col1" class="data row10 col1" >HOU</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row10_col2" class="data row10 col2" >1605</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row11_col0" class="data row11 col0" >12</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row11_col1" class="data row11 col1" >BLT</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row11_col2" class="data row11 col2" >1589</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row12_col0" class="data row12 col0" >13</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row12_col1" class="data row12 col1" >IND</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row12_col2" class="data row12 col2" >1585</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row13_col0" class="data row13 col0" >14</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row13_col1" class="data row13 col1" >CHI</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row13_col2" class="data row13 col2" >1575</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row14_col0" class="data row14 col0" >15</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row14_col1" class="data row14 col1" >DAL</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row14_col2" class="data row14 col2" >1570</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row15_col0" class="data row15 col0" >16</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row15_col1" class="data row15 col1" >SEA</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row15_col2" class="data row15 col2" >1553</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row16_col0" class="data row16 col0" >17</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row16_col1" class="data row16 col1" >TENN</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row16_col2" class="data row16 col2" >1481</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row17_col0" class="data row17 col0" >18</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row17_col1" class="data row17 col1" >DET</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row17_col2" class="data row17 col2" >1477</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row18_col0" class="data row18 col0" >19</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row18_col1" class="data row18 col1" >TB</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row18_col2" class="data row18 col2" >1458</td>
#             </tr>
#             <tr>
#                                 <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row19_col0" class="data row19 col0" >20</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row19_col1" class="data row19 col1" >JAX</td>
#                         <td id="T_8a1972f6_310d_11ea_a347_8c859078f5a0row19_col2" class="data

# %%
# Elo Formula

def update_elo(home, road):
    if (home + 50) > road:
        home = k * (home - 50 - road) + home
        road = k * (road + 50 - home) + road
    else:
        home = home - (k * (home - 50 - road))
        road = k * (road + 50 - home) + road
    return home, road

# %%
# Winner

def winner(home, road)

# %%
# NFL week 1

# gb @ chi 
update_elo(chi, gb)
(chi, gb) = update_elo(chi, gb)

# lar @ car
update_elo(car, lar)
(car, lar) = update_elo(car, lar)

# was @ phi
update_elo(phi, was)
(phi, was) = update_elo(phi, was)

# buf @ nyj
update_elo(nyj, buf)
(nyj, buf) = update_elo(nyj, buf)

# atl @ minn
update_elo(minn, atl)
(minn, atl) = update_elo(minn, atl)

# bal @ mia
update_elo(mia, blt)
(mia, blt) = update_elo(mia, blt)

# kc @ jax
update_elo(jax, kc)
(jax, kc) = update_elo(jax, kc)

# tenn @ cle
update_elo(cle, tenn)
(cle, tenn) = update_elo(cle, tenn)

# ind @ lac
update_elo(lac, ind)
(lac, ind) = update_elo(lac, ind)

# cin @ sea
update_elo(sea, cin)
(sea, cin) = update_elo(sea, cin)

# sf @ tb
update_elo(tb, sf)
(tb, sf) = update_elo(tb, sf)

# nyg @ dal
update_elo(dal, nyg)
(dal, nyg) = update_elo(dal, nyg)

# det @ ari
update_elo(ari, det)
(ari, det) = update_elo(ari, det)

# pitt @ ne
update_elo(ne, pitt)
(ne, pitt) = update_elo(ne, pitt)

# hou @ no
update_elo(no, hou)
(no, hou) = update_elo(no, hou)

# den @ oak
update_elo(oak, den)
(oak, den) = update_elo(oak, den)


table1 = table
table1
# Out:
# <style  type="text/css" >
# </style><table id="T_90898388_310d_11ea_a347_8c859078f5a0" ><thead>    <tr>        <th class="col_heading level0 col0" >Rank</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Elo</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row0_col1" class="data row0 col1" >NO</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row0_col2" class="data row0 col2" >1800</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row1_col1" class="data row1 col1" >NE</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row1_col2" class="data row1 col2" >1800</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row2_col1" class="data row2 col1" >MIN</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row2_col2" class="data row2 col2" >1800</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row3_col1" class="data row3 col1" >PITT</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row3_col2" class="data row3 col2" >1800</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row4_col1" class="data row4 col1" >KC</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row4_col2" class="data row4 col2" >1750</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row5_col1" class="data row5 col1" >LAR</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row5_col2" class="data row5 col2" >1741</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row6_col1" class="data row6 col1" >PHI</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row6_col2" class="data row6 col2" >1664</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row7_col1" class="data row7 col1" >CAR</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row7_col2" class="data row7 col2" >1631</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row8_col0" class="data row8 col0" >9</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row8_col1" class="data row8 col1" >LAC</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row8_col2" class="data row8 col2" >1620</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row9_col0" class="data row9 col0" >10</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row9_col1" class="data row9 col1" >ATL</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row9_col2" class="data row9 col2" >1610</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row10_col0" class="data row10 col0" >11</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row10_col1" class="data row10 col1" >HOU</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row10_col2" class="data row10 col2" >1605</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row11_col0" class="data row11 col0" >12</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row11_col1" class="data row11 col1" >BLT</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row11_col2" class="data row11 col2" >1589</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row12_col0" class="data row12 col0" >13</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row12_col1" class="data row12 col1" >IND</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row12_col2" class="data row12 col2" >1585</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row13_col0" class="data row13 col0" >14</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row13_col1" class="data row13 col1" >CHI</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row13_col2" class="data row13 col2" >1575</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row14_col0" class="data row14 col0" >15</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row14_col1" class="data row14 col1" >DAL</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row14_col2" class="data row14 col2" >1570</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row15_col0" class="data row15 col0" >16</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row15_col1" class="data row15 col1" >SEA</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row15_col2" class="data row15 col2" >1553</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row16_col0" class="data row16 col0" >17</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row16_col1" class="data row16 col1" >TENN</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row16_col2" class="data row16 col2" >1481</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row17_col0" class="data row17 col0" >18</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row17_col1" class="data row17 col1" >DET</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row17_col2" class="data row17 col2" >1477</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row18_col0" class="data row18 col0" >19</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row18_col1" class="data row18 col1" >TB</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row18_col2" class="data row18 col2" >1458</td>
#             </tr>
#             <tr>
#                                 <td id="T_90898388_310d_11ea_a347_8c859078f5a0row19_col0" class="data row19 col0" >20</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row19_col1" class="data row19 col1" >JAX</td>
#                         <td id="T_90898388_310d_11ea_a347_8c859078f5a0row19_col2" class="data
